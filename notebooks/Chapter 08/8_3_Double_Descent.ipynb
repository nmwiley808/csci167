# %% [markdown]
# # **Notebook 8.3: Double Descent**
#
# This notebook investigates double descent as described in section 8.4 of the book.
#
# It uses the MNIST-1D database which can be found at https://github.com/greydanus/mnist1d
#
# Work through the cells below, running each cell in turn. In various places you will see the words "TODO". Follow the instructions at these places and make predictions about what is going to happen or write code to complete the functions.
#
# Contact me at udlbookmail@gmail.com if you find any mistakes or have any suggestions.

# %%
# Run this if you're in a Colab to install MNIST 1D repository
# !pip install git+https://github.com/greydanus/mnist1d

# %%
import torch, torch.nn as nn
from torch.utils.data import TensorDataset, DataLoader
from torch.optim.lr_scheduler import StepLR
import numpy as np
import matplotlib.pyplot as plt
import mnist1d
import random
random.seed(0)

# Try attaching to GPU -- Use "Change Runtime Type to change to GPUT"
DEVICE = str(torch.device('cuda' if torch.cuda.is_available() else 'cpu'))
print('Using:', DEVICE)

# %%
args = mnist1d.data.get_dataset_args()
args.num_samples = 8000
args.train_split = 0.5
args.corr_noise_scale = 0.25
args.iid_noise_scale=2e-2
data = mnist1d.data.get_dataset(args, path='./mnist1d_data.pkl', download=False, regenerate=True)

# Add 15% noise to training labels
for c_y in range(len(data['y'])):
    random_number = random.random()
    if random_number < 0.15 :
        random_int = int(random.random() * 10)
        data['y'][c_y] = random_int

# The training and test input and outputs are in
# data['x'], data['y'], data['x_test'], and data['y_test']
print("Examples in training set: {}".format(len(data['y'])))
print("Examples in test set: {}".format(len(data['y_test'])))
print("Dimensionality of each example: {}".format(data['x'].shape[-1]))

# %%
# Initialize the parameters with He initialization
def weights_init(layer_in):
  if isinstance(layer_in, nn.Linear):
    nn.init.kaiming_uniform_(layer_in.weight)
    layer_in.bias.data.fill_(0.0)

# Return an initialized model with two hidden layers and n_hidden hidden units at each
def get_model(n_hidden):

  D_i = 40    # Input dimensions
  D_k = n_hidden   # Hidden dimensions
  D_o = 10    # Output dimensions

  # Define a model with two hidden layers
  # And ReLU activations between them
  model = nn.Sequential(
  nn.Linear(D_i, D_k),
  nn.ReLU(),
  nn.Linear(D_k, D_k),
  nn.ReLU(),
  nn.Linear(D_k, D_o))

  # Call the function you just defined
  model.apply(weights_init)

  # Return the model
  return model ;

# %%
def fit_model(model, data, n_epoch):

  # choose cross entropy loss function (equation 5.24)
  loss_function = torch.nn.CrossEntropyLoss()
  # construct SGD optimizer and initialize learning rate and momentum
  # optimizer = torch.optim.Adam(model.parameters(), lr=0.01)
  optimizer = torch.optim.SGD(model.parameters(), lr = 0.01, momentum=0.9)


  x_train = torch.tensor(data['x'].astype('float32'))
  y_train = torch.tensor(data['y'].transpose().astype('long'))
  x_test= torch.tensor(data['x_test'].astype('float32'))
  y_test = torch.tensor(data['y_test'].astype('long'))

  # load the data into a class that creates the batches
  data_loader = DataLoader(TensorDataset(x_train,y_train), batch_size=100, shuffle=True, worker_init_fn=np.random.seed(1))

  for epoch in range(n_epoch):
    # loop over batches
    for i, batch in enumerate(data_loader):
      # retrieve inputs and labels for this batch
      x_batch, y_batch = batch
      # zero the parameter gradients
      optimizer.zero_grad()
      # forward pass -- calculate model output
      pred = model(x_batch)
      # compute the loss
      loss = loss_function(pred, y_batch)
      # backward pass
      loss.backward()
      # SGD update
      optimizer.step()

    # Run whole dataset to get statistics -- normally wouldn't do this
    pred_train = model(x_train)
    pred_test = model(x_test)
    _, predicted_train_class = torch.max(pred_train.data, 1)
    _, predicted_test_class = torch.max(pred_test.data, 1)
    errors_train = 100 - 100 * (predicted_train_class == y_train).float().sum() / len(y_train)
    errors_test= 100 - 100 * (predicted_test_class == y_test).float().sum() / len(y_test)
    losses_train = loss_function(pred_train, y_train).item()
    losses_test= loss_function(pred_test, y_test).item()
    if epoch%100 ==0 :
      print(f'Epoch {epoch:5d}, train loss {losses_train:.6f}, train error {errors_train:3.2f},  test loss {losses_test:.6f}, test error {errors_test:3.2f}')

  return errors_train, errors_test

# %%
def count_parameters(model):
    return sum(p.numel() for p in model.parameters() if p.requires_grad)

# %% [markdown]
# The following code produces the double descent curve by training the model with different numbers of hidden units and plotting the test error.
#
# TODO:
#
# *Before* you run the code, and considering that there are 4000 training examples predict:<br>
#
# 1.    At what capacity do you think the training error will become zero?
# 2.   At what capacity do you expect the first minima of the double descent curve to appear?
# 3. At what capacity do you expect the maximum of the double descent curve to appear?

# %%
# This code will take a while (~30 mins on GPU) to run!  Go and make a cup of coffee!

hidden_variables = np.array([2,4,6,8,10,14,18,22,26,30,35,40,45,50,55,60,70,80,90,100,120,140,160,180,200,250,300,400]) ;

errors_train_all = np.zeros_like(hidden_variables)
errors_test_all = np.zeros_like(hidden_variables)
total_weights_all = np.zeros_like(hidden_variables)

# loop over the dataset n_epoch times
n_epoch = 1000

# For each hidden variable size
for c_hidden in range(len(hidden_variables)):
    print(f'Training model with {hidden_variables[c_hidden]:3d} hidden variables')
    # Get a model
    model = get_model(hidden_variables[c_hidden]) ;
    # Count and store number of weights
    total_weights_all[c_hidden] = count_parameters(model)
    # Train the model
    errors_train, errors_test = fit_model(model, data, n_epoch)
    # Store the results
    errors_train_all[c_hidden] = errors_train
    errors_test_all[c_hidden]= errors_test
# Out:
# Training model with   2 hidden variables
# Epoch     0, train loss 2.244590, train error 84.00,  test loss 2.223536, test error 84.05
# Epoch   100, train loss 1.866969, train error 70.00,  test loss 1.721159, test error 68.85
# Epoch   200, train loss 1.856785, train error 69.35,  test loss 1.714593, test error 68.40
# Epoch   300, train loss 1.851748, train error 69.10,  test loss 1.714198, test error 67.88
# Epoch   400, train loss 1.851237, train error 69.65,  test loss 1.707146, test error 68.10
# Epoch   500, train loss 1.847270, train error 70.05,  test loss 1.710237, test error 67.70
# Epoch   600, train loss 1.846665, train error 69.75,  test loss 1.711581, test error 67.00
# Epoch   700, train loss 1.847341, train error 70.22,  test loss 1.705409, test error 68.43
# Epoch   800, train loss 1.846171, train error 69.32,  test loss 1.715645, test error 68.68
# Epoch   900, train loss 1.846703, train error 69.43,  test loss 1.707700, test error 68.47
# Training model with   4 hidden variables
# Epoch     0, train loss 2.296330, train error 90.93,  test loss 2.299754, test error 90.55
# Epoch   100, train loss 1.747202, train error 63.35,  test loss 1.553676, test error 60.20
# Epoch   200, train loss 1.697721, train error 61.25,  test loss 1.483921, test error 56.60
# Epoch   300, train loss 1.684401, train error 60.97,  test loss 1.493304, test error 57.72
# Epoch   400, train loss 1.678072, train error 61.62,  test loss 1.493480, test error 57.25
# Epoch   500, train loss 1.673823, train error 61.15,  test loss 1.501846, test error 57.75
# Epoch   600, train loss 1.669948, train error 60.88,  test loss 1.495092, test error 56.97
# Epoch   700, train loss 1.671796, train error 60.42,  test loss 1.489347, test error 57.33
# Epoch   800, train loss 1.669041, train error 60.25,  test loss 1.500207, test error 57.70
# Epoch   900, train loss 1.668390, train error 60.90,  test loss 1.498395, test error 57.78
# Training model with   6 hidden variables
# Epoch     0, train loss 2.300134, train error 88.93,  test loss 2.306529, test error 88.90
# Epoch   100, train loss 1.795026, train error 65.82,  test loss 1.699973, test error 66.57
# Epoch   200, train loss 1.755955, train error 63.97,  test loss 1.658559, test error 63.20
# Epoch   300, train loss 1.679332, train error 59.45,  test loss 1.550940, test error 57.25
# Epoch   400, train loss 1.626428, train error 57.35,  test loss 1.486276, test error 55.45
# Epoch   500, train loss 1.613348, train error 56.62,  test loss 1.468332, test error 54.85
# Epoch   600, train loss 1.606370, train error 56.33,  test loss 1.462377, test error 54.83
# Epoch   700, train loss 1.573919, train error 55.53,  test loss 1.424227, test error 52.90
# Epoch   800, train loss 1.570062, train error 55.12,  test loss 1.428070, test error 53.15
# Epoch   900, train loss 1.570876, train error 54.83,  test loss 1.423830, test error 53.53
# Training model with   8 hidden variables
# Epoch     0, train loss 2.272473, train error 85.10,  test loss 2.271870, test error 84.90
# Epoch   100, train loss 1.628415, train error 56.72,  test loss 1.468241, test error 54.95
# Epoch   200, train loss 1.591463, train error 54.80,  test loss 1.446072, test error 54.55
# Epoch   300, train loss 1.573260, train error 53.95,  test loss 1.436926, test error 53.22
# Epoch   400, train loss 1.559602, train error 53.85,  test loss 1.448213, test error 53.75
# Epoch   500, train loss 1.551498, train error 53.30,  test loss 1.440421, test error 53.78
# Epoch   600, train loss 1.544766, train error 53.40,  test loss 1.449385, test error 53.25
# Epoch   700, train loss 1.540720, train error 53.10,  test loss 1.450029, test error 53.28
# Epoch   800, train loss 1.533407, train error 52.65,  test loss 1.445069, test error 52.97
# Epoch   900, train loss 1.529238, train error 52.75,  test loss 1.450209, test error 53.25
# Training model with  10 hidden variables
# Epoch     0, train loss 2.230026, train error 81.95,  test loss 2.213137, test error 80.93
# Epoch   100, train loss 1.572580, train error 55.33,  test loss 1.426770, test error 55.35
# Epoch   200, train loss 1.519255, train error 52.97,  test loss 1.398358, test error 53.03
# Epoch   300, train loss 1.472981, train error 51.12,  test loss 1.373104, test error 51.55
# Epoch   400, train loss 1.443450, train error 49.47,  test loss 1.349039, test error 51.03
# Epoch   500, train loss 1.434627, train error 50.10,  test loss 1.370354, test error 50.58
# Epoch   600, train loss 1.417970, train error 48.72,  test loss 1.356288, test error 49.92
# Epoch   700, train loss 1.407367, train error 48.62,  test loss 1.353415, test error 49.30
# Epoch   800, train loss 1.404255, train error 48.47,  test loss 1.353902, test error 49.47
# Epoch   900, train loss 1.407482, train error 48.75,  test loss 1.360626, test error 49.40
# Training model with  14 hidden variables
# Epoch     0, train loss 2.180884, train error 80.65,  test loss 2.150686, test error 79.72
# Epoch   100, train loss 1.364549, train error 45.30,  test loss 1.236576, test error 46.10
# Epoch   200, train loss 1.319223, train error 44.55,  test loss 1.257114, test error 46.92
# Epoch   300, train loss 1.297506, train error 43.78,  test loss 1.285311, test error 47.50
# Epoch   400, train loss 1.283347, train error 43.45,  test loss 1.301868, test error 46.90
# Epoch   500, train loss 1.270309, train error 43.22,  test loss 1.298137, test error 47.00
# Epoch   600, train loss 1.266594, train error 42.78,  test loss 1.321413, test error 47.50
# Epoch   700, train loss 1.258812, train error 42.35,  test loss 1.326504, test error 47.42
# Epoch   800, train loss 1.256755, train error 42.65,  test loss 1.339458, test error 47.97
# Epoch   900, train loss 1.249998, train error 42.55,  test loss 1.344993, test error 47.08
# Training model with  18 hidden variables
# Epoch     0, train loss 2.123399, train error 78.45,  test loss 2.060563, test error 77.78
# Epoch   100, train loss 1.361674, train error 46.60,  test loss 1.346704, test error 51.20
# Epoch   200, train loss 1.264739, train error 42.83,  test loss 1.375601, test error 51.62
# Epoch   300, train loss 1.232352, train error 41.30,  test loss 1.414743, test error 51.20
# Epoch   400, train loss 1.200127, train error 39.97,  test loss 1.454578, test error 51.75
# Epoch   500, train loss 1.184735, train error 40.12,  test loss 1.496695, test error 52.55
# Epoch   600, train loss 1.166341, train error 39.67,  test loss 1.525607, test error 52.90
# Epoch   700, train loss 1.158147, train error 39.45,  test loss 1.548847, test error 52.92
# Epoch   800, train loss 1.139748, train error 39.15,  test loss 1.570009, test error 53.40
# Epoch   900, train loss 1.135779, train error 38.53,  test loss 1.594615, test error 53.20
# Training model with  22 hidden variables
# Epoch     0, train loss 2.202434, train error 81.00,  test loss 2.193926, test error 81.32
# Epoch   100, train loss 1.293511, train error 42.22,  test loss 1.303599, test error 49.15
# Epoch   200, train loss 1.162164, train error 38.53,  test loss 1.356673, test error 50.17
# Epoch   300, train loss 1.118279, train error 38.83,  test loss 1.452419, test error 51.83
# Epoch   400, train loss 1.079874, train error 36.67,  test loss 1.461028, test error 51.10
# Epoch   500, train loss 1.044579, train error 36.00,  test loss 1.523526, test error 52.70
# Epoch   600, train loss 1.022428, train error 35.70,  test loss 1.544716, test error 53.33
# Epoch   700, train loss 1.011238, train error 34.62,  test loss 1.605457, test error 54.00
# Epoch   800, train loss 0.994406, train error 34.88,  test loss 1.628134, test error 53.65
# Epoch   900, train loss 0.990439, train error 34.95,  test loss 1.686653, test error 54.35
# Training model with  26 hidden variables
# Epoch     0, train loss 2.192888, train error 81.80,  test loss 2.161227, test error 79.90
# Epoch   100, train loss 1.161674, train error 38.78,  test loss 1.289223, test error 47.95
# Epoch   200, train loss 1.018659, train error 34.05,  test loss 1.428646, test error 49.40
# Epoch   300, train loss 0.952261, train error 32.12,  test loss 1.555068, test error 50.62
# Epoch   400, train loss 0.919557, train error 30.62,  test loss 1.685728, test error 51.62
# Epoch   500, train loss 0.883459, train error 30.00,  test loss 1.782205, test error 51.45
# Epoch   600, train loss 0.861237, train error 29.12,  test loss 1.884762, test error 53.05
# Epoch   700, train loss 0.840959, train error 28.30,  test loss 1.967740, test error 53.40
# Epoch   800, train loss 0.826253, train error 27.62,  test loss 2.054933, test error 54.08
# Epoch   900, train loss 0.819064, train error 27.85,  test loss 2.132054, test error 54.03
# Training model with  30 hidden variables
# Epoch     0, train loss 2.144306, train error 80.30,  test loss 2.114861, test error 79.47
# Epoch   100, train loss 1.124091, train error 36.83,  test loss 1.393203, test error 50.08
# Epoch   200, train loss 0.937684, train error 30.82,  test loss 1.569469, test error 51.42
# Epoch   300, train loss 0.854361, train error 28.62,  test loss 1.726956, test error 51.60
# Epoch   400, train loss 0.789015, train error 26.03,  test loss 1.866274, test error 52.72
# Epoch   500, train loss 0.765539, train error 25.68,  test loss 2.032219, test error 54.45
# Epoch   600, train loss 0.731316, train error 24.72,  test loss 2.151293, test error 54.50
# Epoch   700, train loss 0.703156, train error 23.55,  test loss 2.249152, test error 53.62
# Epoch   800, train loss 0.682216, train error 23.43,  test loss 2.324127, test error 53.97
# Epoch   900, train loss 0.698091, train error 23.72,  test loss 2.387399, test error 53.40
# Training model with  35 hidden variables
# Epoch     0, train loss 2.146302, train error 79.95,  test loss 2.118602, test error 78.40
# Epoch   100, train loss 0.996262, train error 32.95,  test loss 1.357962, test error 47.95
# Epoch   200, train loss 0.779361, train error 25.03,  test loss 1.680835, test error 50.78
# Epoch   300, train loss 0.671939, train error 22.93,  test loss 2.044213, test error 52.80
# Epoch   400, train loss 0.594659, train error 19.65,  test loss 2.406027, test error 54.88
# Epoch   500, train loss 0.533296, train error 18.03,  test loss 2.774374, test error 54.88
# Epoch   600, train loss 0.473386, train error 15.78,  test loss 3.193749, test error 55.20
# Epoch   700, train loss 0.439189, train error 14.95,  test loss 3.559558, test error 55.97
# Epoch   800, train loss 0.417421, train error 13.43,  test loss 3.964036, test error 56.80
# Epoch   900, train loss 0.412986, train error 13.47,  test loss 4.373374, test error 56.58
# Training model with  40 hidden variables
# Epoch     0, train loss 2.103241, train error 78.95,  test loss 2.068661, test error 80.00
# Epoch   100, train loss 0.936214, train error 30.18,  test loss 1.498970, test error 51.53
# Epoch   200, train loss 0.651687, train error 20.28,  test loss 1.998310, test error 54.60
# Epoch   300, train loss 0.523738, train error 16.70,  test loss 2.687145, test error 56.35
# Epoch   400, train loss 0.431391, train error 14.00,  test loss 3.343168, test error 57.22
# Epoch   500, train loss 0.393694, train error 12.70,  test loss 4.080703, test error 58.12
# Epoch   600, train loss 0.316549, train error 10.50,  test loss 4.734190, test error 58.67
# Epoch   700, train loss 0.289047, train error 9.50,  test loss 5.458137, test error 58.53
# Epoch   800, train loss 0.278750, train error 9.35,  test loss 6.020946, test error 59.45
# Epoch   900, train loss 0.331181, train error 11.47,  test loss 6.567492, test error 59.60
# Training model with  45 hidden variables
# Epoch     0, train loss 2.075342, train error 76.97,  test loss 2.020526, test error 77.05
# Epoch   100, train loss 0.801799, train error 26.00,  test loss 1.480409, test error 49.05
# Epoch   200, train loss 0.467809, train error 14.40,  test loss 2.221368, test error 53.08
# Epoch   300, train loss 0.270762, train error 7.62,  test loss 3.306987, test error 55.38
# Epoch   400, train loss 0.234726, train error 7.82,  test loss 4.567708, test error 55.53
# Epoch   500, train loss 0.169858, train error 5.88,  test loss 5.835479, test error 56.40
# Epoch   600, train loss 0.147832, train error 4.95,  test loss 7.100521, test error 56.53
# Epoch   700, train loss 0.013462, train error 0.00,  test loss 8.077507, test error 56.75
# Epoch   800, train loss 0.008550, train error 0.00,  test loss 8.774514, test error 56.72
# Epoch   900, train loss 0.006311, train error 0.00,  test loss 9.299150, test error 56.70
# Training model with  50 hidden variables
# Epoch     0, train loss 2.064253, train error 76.50,  test loss 2.033396, test error 75.62
# Epoch   100, train loss 0.731241, train error 22.82,  test loss 1.557919, test error 51.70
# Epoch   200, train loss 0.355570, train error 11.03,  test loss 2.564521, test error 55.53
# Epoch   300, train loss 0.151680, train error 3.85,  test loss 4.095870, test error 56.12
# Epoch   400, train loss 0.030182, train error 0.00,  test loss 5.739641, test error 57.38
# Epoch   500, train loss 0.014111, train error 0.00,  test loss 6.766405, test error 57.15
# Epoch   600, train loss 0.008637, train error 0.00,  test loss 7.437218, test error 57.12
# Epoch   700, train loss 0.006110, train error 0.00,  test loss 7.934953, test error 57.30
# Epoch   800, train loss 0.004708, train error 0.00,  test loss 8.333102, test error 57.35
# Epoch   900, train loss 0.003793, train error 0.00,  test loss 8.661772, test error 57.28
# Training model with  55 hidden variables
# Epoch     0, train loss 2.070607, train error 76.28,  test loss 2.045659, test error 75.95
# Epoch   100, train loss 0.673521, train error 20.40,  test loss 1.697728, test error 52.40
# Epoch   200, train loss 0.284359, train error 7.95,  test loss 3.035362, test error 54.90
# Epoch   300, train loss 0.059947, train error 0.20,  test loss 4.723606, test error 56.50
# Epoch   400, train loss 0.017535, train error 0.00,  test loss 6.008521, test error 56.83
# Epoch   500, train loss 0.009672, train error 0.00,  test loss 6.714172, test error 56.60
# Epoch   600, train loss 0.006221, train error 0.00,  test loss 7.246716, test error 56.58
# Epoch   700, train loss 0.004587, train error 0.00,  test loss 7.631551, test error 56.75
# Epoch   800, train loss 0.003556, train error 0.00,  test loss 7.948272, test error 56.70
# Epoch   900, train loss 0.002909, train error 0.00,  test loss 8.204600, test error 56.65
# Training model with  60 hidden variables
# Epoch     0, train loss 2.062216, train error 76.85,  test loss 1.990472, test error 76.07
# Epoch   100, train loss 0.546736, train error 15.93,  test loss 1.731521, test error 51.83
# Epoch   200, train loss 0.111768, train error 1.28,  test loss 3.248075, test error 53.45
# Epoch   300, train loss 0.019516, train error 0.00,  test loss 4.593350, test error 54.20
# Epoch   400, train loss 0.009498, train error 0.00,  test loss 5.264793, test error 54.58
# Epoch   500, train loss 0.005951, train error 0.00,  test loss 5.709320, test error 54.42
# Epoch   600, train loss 0.004274, train error 0.00,  test loss 6.030869, test error 54.42
# Epoch   700, train loss 0.003278, train error 0.00,  test loss 6.293046, test error 54.53
# Epoch   800, train loss 0.002635, train error 0.00,  test loss 6.506609, test error 54.42
# Epoch   900, train loss 0.002192, train error 0.00,  test loss 6.688195, test error 54.47
# Training model with  70 hidden variables
# Epoch     0, train loss 2.024062, train error 76.28,  test loss 1.967957, test error 76.07
# Epoch   100, train loss 0.356808, train error 9.32,  test loss 1.978069, test error 52.00
# Epoch   200, train loss 0.031849, train error 0.00,  test loss 3.621299, test error 54.55
# Epoch   300, train loss 0.010608, train error 0.00,  test loss 4.386146, test error 54.58
# Epoch   400, train loss 0.005990, train error 0.00,  test loss 4.823252, test error 54.65
# Epoch   500, train loss 0.004052, train error 0.00,  test loss 5.115859, test error 54.88
# Epoch   600, train loss 0.003003, train error 0.00,  test loss 5.343547, test error 54.88
# Epoch   700, train loss 0.002360, train error 0.00,  test loss 5.529061, test error 54.78
# Epoch   800, train loss 0.001931, train error 0.00,  test loss 5.681425, test error 54.70
# Epoch   900, train loss 0.001622, train error 0.00,  test loss 5.815916, test error 54.70
# Training model with  80 hidden variables
# Epoch     0, train loss 2.006866, train error 74.00,  test loss 1.942849, test error 73.95
# Epoch   100, train loss 0.247143, train error 4.85,  test loss 2.054883, test error 51.90
# Epoch   200, train loss 0.019868, train error 0.00,  test loss 3.442102, test error 51.55
# Epoch   300, train loss 0.007948, train error 0.00,  test loss 3.998621, test error 51.90
# Epoch   400, train loss 0.004703, train error 0.00,  test loss 4.329348, test error 52.08
# Epoch   500, train loss 0.003233, train error 0.00,  test loss 4.562399, test error 52.08
# Epoch   600, train loss 0.002432, train error 0.00,  test loss 4.741631, test error 52.17
# Epoch   700, train loss 0.001929, train error 0.00,  test loss 4.891082, test error 52.28
# Epoch   800, train loss 0.001589, train error 0.00,  test loss 5.013998, test error 52.33
# Epoch   900, train loss 0.001343, train error 0.00,  test loss 5.123056, test error 52.33
# Training model with  90 hidden variables
# Epoch     0, train loss 1.992549, train error 73.72,  test loss 1.943950, test error 74.57
# Epoch   100, train loss 0.152157, train error 1.28,  test loss 2.199486, test error 50.90
# Epoch   200, train loss 0.015916, train error 0.00,  test loss 3.259361, test error 51.50
# Epoch   300, train loss 0.006867, train error 0.00,  test loss 3.693257, test error 51.53
# Epoch   400, train loss 0.004141, train error 0.00,  test loss 3.967896, test error 51.67
# Epoch   500, train loss 0.002905, train error 0.00,  test loss 4.164344, test error 51.65
# Epoch   600, train loss 0.002205, train error 0.00,  test loss 4.315567, test error 51.58
# Epoch   700, train loss 0.001760, train error 0.00,  test loss 4.440108, test error 51.67
# Epoch   800, train loss 0.001455, train error 0.00,  test loss 4.547132, test error 51.78
# Epoch   900, train loss 0.001234, train error 0.00,  test loss 4.638282, test error 51.80
# Training model with 100 hidden variables
# Epoch     0, train loss 1.978307, train error 74.20,  test loss 1.910664, test error 73.00
# Epoch   100, train loss 0.081002, train error 0.10,  test loss 2.219835, test error 50.85
# Epoch   200, train loss 0.011683, train error 0.00,  test loss 3.050596, test error 51.60
# Epoch   300, train loss 0.005505, train error 0.00,  test loss 3.393342, test error 51.62
# Epoch   400, train loss 0.003434, train error 0.00,  test loss 3.615506, test error 51.88
# Epoch   500, train loss 0.002448, train error 0.00,  test loss 3.776151, test error 51.80
# Epoch   600, train loss 0.001876, train error 0.00,  test loss 3.904385, test error 51.90
# Epoch   700, train loss 0.001508, train error 0.00,  test loss 4.007213, test error 51.83
# Epoch   800, train loss 0.001253, train error 0.00,  test loss 4.096645, test error 51.97
# Epoch   900, train loss 0.001069, train error 0.00,  test loss 4.173599, test error 52.03
# Training model with 120 hidden variables
# Epoch     0, train loss 1.967356, train error 71.45,  test loss 1.888937, test error 73.10
# Epoch   100, train loss 0.052781, train error 0.07,  test loss 2.206752, test error 49.65
# Epoch   200, train loss 0.009594, train error 0.00,  test loss 2.839679, test error 50.12
# Epoch   300, train loss 0.004710, train error 0.00,  test loss 3.123859, test error 50.38
# Epoch   400, train loss 0.002998, train error 0.00,  test loss 3.308054, test error 50.38
# Epoch   500, train loss 0.002161, train error 0.00,  test loss 3.442289, test error 50.42
# Epoch   600, train loss 0.001668, train error 0.00,  test loss 3.548684, test error 50.42
# Epoch   700, train loss 0.001348, train error 0.00,  test loss 3.635972, test error 50.53
# Epoch   800, train loss 0.001124, train error 0.00,  test loss 3.709842, test error 50.45
# Epoch   900, train loss 0.000960, train error 0.00,  test loss 3.774501, test error 50.50
# Training model with 140 hidden variables
# Epoch     0, train loss 1.959922, train error 71.97,  test loss 1.887302, test error 73.78
# Epoch   100, train loss 0.036729, train error 0.00,  test loss 2.238861, test error 50.90
# Epoch   200, train loss 0.008150, train error 0.00,  test loss 2.736564, test error 50.80
# Epoch   300, train loss 0.004169, train error 0.00,  test loss 2.980494, test error 50.75
# Epoch   400, train loss 0.002704, train error 0.00,  test loss 3.136340, test error 50.55
# Epoch   500, train loss 0.001967, train error 0.00,  test loss 3.251083, test error 50.58
# Epoch   600, train loss 0.001530, train error 0.00,  test loss 3.342980, test error 50.53
# Epoch   700, train loss 0.001242, train error 0.00,  test loss 3.419770, test error 50.50
# Epoch   800, train loss 0.001041, train error 0.00,  test loss 3.485522, test error 50.38
# Epoch   900, train loss 0.000892, train error 0.00,  test loss 3.543207, test error 50.45
# Training model with 160 hidden variables
# Epoch     0, train loss 1.950441, train error 71.45,  test loss 1.910524, test error 74.00
# Epoch   100, train loss 0.028350, train error 0.00,  test loss 2.161875, test error 49.55
# Epoch   200, train loss 0.007217, train error 0.00,  test loss 2.589073, test error 49.55
# Epoch   300, train loss 0.003790, train error 0.00,  test loss 2.794437, test error 49.60
# Epoch   400, train loss 0.002494, train error 0.00,  test loss 2.930865, test error 49.62
# Epoch   500, train loss 0.001828, train error 0.00,  test loss 3.033940, test error 49.70
# Epoch   600, train loss 0.001426, train error 0.00,  test loss 3.116308, test error 49.78
# Epoch   700, train loss 0.001162, train error 0.00,  test loss 3.183524, test error 49.65
# Epoch   800, train loss 0.000975, train error 0.00,  test loss 3.241770, test error 49.62
# Epoch   900, train loss 0.000837, train error 0.00,  test loss 3.292779, test error 49.67
# Training model with 180 hidden variables
# Epoch     0, train loss 1.928446, train error 71.93,  test loss 1.885905, test error 72.57
# Epoch   100, train loss 0.024391, train error 0.00,  test loss 2.038926, test error 47.12
# Epoch   200, train loss 0.006655, train error 0.00,  test loss 2.396726, test error 47.05
# Epoch   300, train loss 0.003578, train error 0.00,  test loss 2.576226, test error 47.25
# Epoch   400, train loss 0.002362, train error 0.00,  test loss 2.696242, test error 47.35
# Epoch   500, train loss 0.001739, train error 0.00,  test loss 2.786216, test error 47.30
# Epoch   600, train loss 0.001362, train error 0.00,  test loss 2.859643, test error 47.20
# Epoch   700, train loss 0.001112, train error 0.00,  test loss 2.919454, test error 47.08
# Epoch   800, train loss 0.000935, train error 0.00,  test loss 2.971292, test error 47.08
# Epoch   900, train loss 0.000804, train error 0.00,  test loss 3.015964, test error 47.05
# Training model with 200 hidden variables
# Epoch     0, train loss 1.916582, train error 69.55,  test loss 1.829434, test error 71.88
# Epoch   100, train loss 0.021307, train error 0.00,  test loss 2.040290, test error 48.00
# Epoch   200, train loss 0.006113, train error 0.00,  test loss 2.368803, test error 48.17
# Epoch   300, train loss 0.003318, train error 0.00,  test loss 2.538358, test error 48.10
# Epoch   400, train loss 0.002217, train error 0.00,  test loss 2.652895, test error 48.08
# Epoch   500, train loss 0.001638, train error 0.00,  test loss 2.738233, test error 48.05
# Epoch   600, train loss 0.001288, train error 0.00,  test loss 2.807898, test error 48.12
# Epoch   700, train loss 0.001054, train error 0.00,  test loss 2.864826, test error 48.08
# Epoch   800, train loss 0.000888, train error 0.00,  test loss 2.914753, test error 48.05
# Epoch   900, train loss 0.000764, train error 0.00,  test loss 2.958023, test error 48.08
# Training model with 250 hidden variables
# Epoch     0, train loss 1.890401, train error 68.38,  test loss 1.812263, test error 70.80
# Epoch   100, train loss 0.016948, train error 0.00,  test loss 1.920610, test error 47.38
# Epoch   200, train loss 0.005327, train error 0.00,  test loss 2.182381, test error 47.47
# Epoch   300, train loss 0.002968, train error 0.00,  test loss 2.319800, test error 47.50
# Epoch   400, train loss 0.002005, train error 0.00,  test loss 2.415991, test error 47.53
# Epoch   500, train loss 0.001493, train error 0.00,  test loss 2.488538, test error 47.35
# Epoch   600, train loss 0.001179, train error 0.00,  test loss 2.547642, test error 47.20
# Epoch   700, train loss 0.000968, train error 0.00,  test loss 2.596547, test error 47.28
# Epoch   800, train loss 0.000817, train error 0.00,  test loss 2.638628, test error 47.22
# Epoch   900, train loss 0.000705, train error 0.00,  test loss 2.675958, test error 47.22
# Training model with 300 hidden variables
# Epoch     0, train loss 1.861384, train error 67.53,  test loss 1.788298, test error 69.60
# Epoch   100, train loss 0.014652, train error 0.00,  test loss 1.870815, test error 46.72
# Epoch   200, train loss 0.004870, train error 0.00,  test loss 2.086528, test error 46.78
# Epoch   300, train loss 0.002757, train error 0.00,  test loss 2.205567, test error 46.83
# Epoch   400, train loss 0.001876, train error 0.00,  test loss 2.286295, test error 46.72
# Epoch   500, train loss 0.001403, train error 0.00,  test loss 2.348220, test error 46.67
# Epoch   600, train loss 0.001111, train error 0.00,  test loss 2.398183, test error 46.80
# Epoch   700, train loss 0.000915, train error 0.00,  test loss 2.440088, test error 46.78
# Epoch   800, train loss 0.000774, train error 0.00,  test loss 2.476743, test error 46.85
# Epoch   900, train loss 0.000669, train error 0.00,  test loss 2.508274, test error 46.88
# Training model with 400 hidden variables
# Epoch     0, train loss 1.859720, train error 67.43,  test loss 1.801913, test error 69.53
# Epoch   100, train loss 0.011689, train error 0.00,  test loss 1.813501, test error 46.00
# Epoch   200, train loss 0.004175, train error 0.00,  test loss 1.998705, test error 45.92
# Epoch   300, train loss 0.002416, train error 0.00,  test loss 2.100645, test error 45.75
# Epoch   400, train loss 0.001664, train error 0.00,  test loss 2.171286, test error 45.80
# Epoch   500, train loss 0.001254, train error 0.00,  test loss 2.226318, test error 45.83
# Epoch   600, train loss 0.000998, train error 0.00,  test loss 2.270857, test error 45.70
# Epoch   700, train loss 0.000825, train error 0.00,  test loss 2.307874, test error 45.78
# Epoch   800, train loss 0.000700, train error 0.00,  test loss 2.340216, test error 45.85
# Epoch   900, train loss 0.000606, train error 0.00,  test loss 2.368865, test error 45.83

# %%
import matplotlib.pyplot as plt
import numpy as np

# Assuming data['y'] is available and contains the training examples
num_training_examples = len(data['y'])

# Find the index where total_weights_all is closest to num_training_examples
closest_index = np.argmin(np.abs(np.array(total_weights_all) - num_training_examples))

# Get the corresponding value of hidden variables
hidden_variable_at_num_training_examples = hidden_variables[closest_index]

# Plot the results
fig, ax = plt.subplots()
ax.plot(hidden_variables, errors_train_all, 'r-', label='train')
ax.plot(hidden_variables, errors_test_all, 'b-', label='test')

# Add a vertical line at the point where total weights equal the number of training examples
ax.axvline(x=hidden_variable_at_num_training_examples, color='g', linestyle='--', label='N(weights) = N(train)')

ax.set_ylim(0, 100)
ax.set_xlabel('No. hidden variables')
ax.set_ylabel('Error')
ax.legend()
plt.show()
